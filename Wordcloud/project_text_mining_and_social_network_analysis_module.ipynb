# %%
import numpy as np
import pandas as pd
import nltk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
source_path = '/content/drive/My Drive/Bootcamp-DS/Module3/data/project/'

# %% [markdown]
# # Generate CSV

# %% [markdown]
# ## Load json

# %%
# prompt: dame un ejemplo para leer un json en diccionario

import json

with open(source_path + 'cafe_de_tere.json') as f:
  data = json.load(f)

data['tweets'][:2]
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Nov 08 00:38:50 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 148085509,
#      'id_str': '148085509',
#      'indices': [3, 18],
#      'name': 'Joaquín Saavedra',
#      'screen_name': 'joacosaavedraq'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1192602342434234371,
#   'id_str': '1192602342434234371',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'place': None,
#   'retweet_count': 18,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Nov 06 21:48:16 +0000 2019',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1192197028559937544',
#       'indices': [117, 140],
#       'url': 'https://t.co/4AfTqVPVRq'}],
#     'user_mentions': []},
#    'favorite_count': 86,
#    'favorited': False,
#    'geo': None,
#    'id': 1192197028559937544,
#    'id_str': '1192197028559937544',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'place': None,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'retweet_count': 18,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Larga vida al bolón mixto de maduro de Tere. En la vida siempre están los que se quedan criticando y los que dan el… https://t.co/4AfTqVPVRq',
#    'truncated': True,
#    'user': {'can_media_tag': True,
#     'contributors_enabled': False,
#     'created_at': 'Tue May 25 20:13:42 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Periodista Deportivo: Fanático Ecuadortv, @f_sin_cassette , ”Al Toque” Radio Caravana, “Minuto Cero” Diblu, DT infanto juvenil @campusatfa, árbitro (2017)',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'youtu.be/6PnBIHvHd-8',
#         'expanded_url': 'https://youtu.be/6PnBIHvHd-8',
#         'indices': [0, 23],
#         'url': 'https://t.co/ZPoJfNK3Dd'}]}},
#     'favourites_count': 3834,
#     'follow_request_sent': False,
#     'followed_by': False,
#     'followers_count': 8647,
#     'following': True,
#     'friends_count': 1103,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 148085509,
#     'id_str': '148085509',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 34,
#     'location': 'Guayaquil',
#     'name': 'Joaquín Saavedra',
#     'notifications': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/148085509/1572558455',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1191573757367848961/mPKmegYW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1191573757367848961/mPKmegYW_normal.jpg',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'joacosaavedraq',
#     'statuses_count': 23008,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/ZPoJfNK3Dd',
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @joacosaavedraq: Larga vida al bolón mixto de maduro de Tere. En la vida siempre están los que se quedan criticando y los que dan el pas…',
#   'truncated': False,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Tue Sep 07 04:01:41 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1512,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 224,
#    'following': False,
#    'friends_count': 397,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 187786406,
#    'id_str': '187786406',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 1,
#    'location': 'Guayaquil',
#    'name': 'César Jurado',
#    'notifications': False,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/187786406/1490627928',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/902500857480138752/JB4PhH9Q_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/902500857480138752/JB4PhH9Q_normal.jpg',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'cesar_jurado',
#    'statuses_count': 9262,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Nov 08 00:31:15 +0000 2019',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1192600432020996097',
#      'indices': [117, 140],
#      'url': 'https://t.co/3FEAreQUwe'}],
#    'user_mentions': [{'id': 83445710,
#      'id_str': '83445710',
#      'indices': [0, 14],
#      'name': 'FranFerrero',
#      'screen_name': 'FranFerreroMD'},
#     {'id': 846167661730025476,
#      'id_str': '846167661730025476',
#      'indices': [15, 31],
#      'name': 'fraguaciudadana',
#      'screen_name': 'fraguaciudadana'}]},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 1192600432020996097,
#   'id_str': '1192600432020996097',
#   'in_reply_to_screen_name': 'FranFerreroMD',
#   'in_reply_to_status_id': 1191921192376119296,
#   'in_reply_to_status_id_str': '1191921192376119296',
#   'in_reply_to_user_id': 83445710,
#   'in_reply_to_user_id_str': '83445710',
#   'is_quote_status': False,
#   'lang': 'es',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-80.4676050033072, -3.06371600046572],
#       [-79.7147810026682, -3.06371600046572],
#       [-79.7147810026682, -1.96227400010509],
#       [-80.4676050033072, -1.96227400010509]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'Ecuador',
#    'country_code': 'EC',
#    'full_name': 'Guayaquil, Ecuador',
#    'id': '009924a469d7ace1',
#    'name': 'Guayaquil',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/009924a469d7ace1.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@FranFerreroMD @fraguaciudadana Buenas, estimada creo que el nacimiento del bolon de tere se remonta a los años 199… https://t.co/3FEAreQUwe',
#   'truncated': True,
#   'user': {'can_media_tag': True,
#    'contributors_enabled': False,
#    'created_at': 'Sat Oct 05 21:11:54 +0000 2013',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 38,
#    'follow_request_sent': False,
#    'followed_by': False,
#    'followers_count': 37,
#    'following': False,
#    'friends_count': 28,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 1938863000,
#    'id_str': '1938863000',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 0,
#    'location': 'Guayas, Ecuador',
#    'name': 'carlos donoso',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1938863000/1464057698',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000553874031/1dedcf671b4928e6e39154cc37b850f6_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000553874031/1dedcf671b4928e6e39154cc37b850f6_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'donoso_molina',
#    'statuses_count': 168,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]

# %%
print(len(data))
# Out:
# 1

# %% [markdown]
# ## Understanding the data

# %%
#@title Example of the content of one of the tweets.
"""
        {
            "contributors": null,
            "coordinates": null,
            "created_at": "Fri Nov 08 00:38:50 +0000 2019",
            "entities": {
                "hashtags": [],
                "symbols": [],
                "urls": [],
                "user_mentions": [
                    {
                        "id": 148085509,
                        "id_str": "148085509",
                        "indices": [
                            3,
                            18
                        ],
                        "name": "Joaqu\u00edn Saavedra",
                        "screen_name": "joacosaavedraq"
                    }
                ]
            },
            "favorite_count": 0,
            "favorited": false,
            "geo": null,
            "id": 1192602342434234371,
            "id_str": "1192602342434234371",
            "in_reply_to_screen_name": null,
            "in_reply_to_status_id": null,
            "in_reply_to_status_id_str": null,
            "in_reply_to_user_id": null,
            "in_reply_to_user_id_str": null,
            "is_quote_status": false,
            "lang": "es",
            "place": null,
            "retweet_count": 18,
            "retweeted": false,
            "retweeted_status": {
                "contributors": null,
                "coordinates": null,
                "created_at": "Wed Nov 06 21:48:16 +0000 2019",
                "entities": {
                    "hashtags": [],
                    "symbols": [],
                    "urls": [
                        {
                            "display_url": "twitter.com/i/web/status/1\u2026",
                            "expanded_url": "https://twitter.com/i/web/status/1192197028559937544",
                            "indices": [
                                117,
                                140
                            ],
                            "url": "https://t.co/4AfTqVPVRq"
                        }
                    ],
                    "user_mentions": []
                },
                "favorite_count": 86,
                "favorited": false,
                "geo": null,
                "id": 1192197028559937544,
                "id_str": "1192197028559937544",
                "in_reply_to_screen_name": null,
                "in_reply_to_status_id": null,
                "in_reply_to_status_id_str": null,
                "in_reply_to_user_id": null,
                "in_reply_to_user_id_str": null,
                "is_quote_status": false,
                "lang": "es",
                "place": null,
                "possibly_sensitive": false,
                "possibly_sensitive_appealable": false,
                "retweet_count": 18,
                "retweeted": false,
                "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
                "text": "Larga vida al bol\u00f3n mixto de maduro de Tere. En la vida siempre est\u00e1n los que se quedan criticando y los que dan el\u2026 https://t.co/4AfTqVPVRq",
                "truncated": true,
                "user": {
                    "can_media_tag": true,
                    "contributors_enabled": false,
                    "created_at": "Tue May 25 20:13:42 +0000 2010",
                    "default_profile": false,
                    "default_profile_image": false,
                    "description": "Periodista Deportivo: Fan\u00e1tico Ecuadortv, @f_sin_cassette , \u201dAl Toque\u201d Radio Caravana, \u201cMinuto Cero\u201d Diblu, DT infanto juvenil @campusatfa, \u00e1rbitro (2017)",
                    "entities": {
                        "description": {
                            "urls": []
                        },
                        "url": {
                            "urls": [
                                {
                                    "display_url": "youtu.be/6PnBIHvHd-8",
                                    "expanded_url": "https://youtu.be/6PnBIHvHd-8",
                                    "indices": [
                                        0,
                                        23
                                    ],
                                    "url": "https://t.co/ZPoJfNK3Dd"
                                }
                            ]
                        }
                    },
                    "favourites_count": 3834,
                    "follow_request_sent": false,
                    "followed_by": false,
                    "followers_count": 8647,
                    "following": true,
                    "friends_count": 1103,
                    "geo_enabled": false,
                    "has_extended_profile": true,
                    "id": 148085509,
                    "id_str": "148085509",
                    "is_translation_enabled": false,
                    "is_translator": false,
                    "lang": null,
                    "listed_count": 34,
                    "location": "Guayaquil",
                    "name": "Joaqu\u00edn Saavedra",
                    "notifications": false,
                    "profile_background_color": "131516",
                    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
                    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
                    "profile_background_tile": true,
                    "profile_banner_url": "https://pbs.twimg.com/profile_banners/148085509/1572558455",
                    "profile_image_url": "http://pbs.twimg.com/profile_images/1191573757367848961/mPKmegYW_normal.jpg",
                    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1191573757367848961/mPKmegYW_normal.jpg",
                    "profile_link_color": "009999",
                    "profile_sidebar_border_color": "EEEEEE",
                    "profile_sidebar_fill_color": "EFEFEF",
                    "profile_text_color": "333333",
                    "profile_use_background_image": true,
                    "protected": false,
                    "screen_name": "joacosaavedraq",
                    "statuses_count": 23008,
                    "time_zone": null,
                    "translator_type": "none",
                    "url": "https://t.co/ZPoJfNK3Dd",
                    "utc_offset": null,
                    "verified": false
                }
            },
            "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
            "text": "RT @joacosaavedraq: Larga vida al bol\u00f3n mixto de maduro de Tere. En la vida siempre est\u00e1n los que se quedan criticando y los que dan el pas\u2026",
            "truncated": false,
            "user": {
                "can_media_tag": true,
                "contributors_enabled": false,
                "created_at": "Tue Sep 07 04:01:41 +0000 2010",
                "default_profile": false,
                "default_profile_image": false,
                "description": "",
                "entities": {
                    "description": {
                        "urls": []
                    }
                },
                "favourites_count": 1512,
                "follow_request_sent": false,
                "followed_by": false,
                "followers_count": 224,
                "following": false,
                "friends_count": 397,
                "geo_enabled": true,
                "has_extended_profile": true,
                "id": 187786406,
                "id_str": "187786406",
                "is_translation_enabled": false,
                "is_translator": false,
                "lang": null,
                "listed_count": 1,
                "location": "Guayaquil",
                "name": "C\u00e9sar Jurado",
                "notifications": false,
                "profile_background_color": "131516",
                "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
                "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
                "profile_background_tile": true,
                "profile_banner_url": "https://pbs.twimg.com/profile_banners/187786406/1490627928",
                "profile_image_url": "http://pbs.twimg.com/profile_images/902500857480138752/JB4PhH9Q_normal.jpg",
                "profile_image_url_https": "https://pbs.twimg.com/profile_images/902500857480138752/JB4PhH9Q_normal.jpg",
                "profile_link_color": "009999",
                "profile_sidebar_border_color": "EEEEEE",
                "profile_sidebar_fill_color": "EFEFEF",
                "profile_text_color": "333333",
                "profile_use_background_image": true,
                "protected": false,
                "screen_name": "cesar_jurado",
                "statuses_count": 9262,
                "time_zone": null,
                "translator_type": "none",
                "url": null,
                "utc_offset": null,
                "verified": false
            }
        },
"""
# Out:
# '\n        {\n            "contributors": null,\n            "coordinates": null,\n            "created_at": "Fri Nov 08 00:38:50 +0000 2019",\n            "entities": {\n                "hashtags": [],\n                "symbols": [],\n                "urls": [],\n                "user_mentions": [\n                    {\n                        "id": 148085509,\n                        "id_str": "148085509",\n                        "indices": [\n                            3,\n                            18\n                        ],\n                        "name": "Joaquín Saavedra",\n                        "screen_name": "joacosaavedraq"\n                    }\n                ]\n            },\n            "favorite_count": 0,\n            "favorited": false,\n            "geo": null,\n            "id": 1192602342434234371,\n            "id_str": "1192602342434234371",\n            "in_reply_to_screen_name": null,\n            "in_reply_to_status_id": null,\n            "in_reply_to_status_id_str": null,\n            "in_reply_to_user_id": null,\n            "in_reply_to_user_id_str": null,\n            "is_quote_status": false,\n            "lang": "es",\n            "place": null,\n            "retweet_count": 18,\n            "retweeted": false,\n            "retweeted_status": {\n                "contributors": null,\n                "coordinates": null,\n                "created_at": "Wed Nov 06 21:48:16 +0000 2019",\n                "entities": {\n                    "hashtags": [],\n                    "symbols": [],\n                    "urls": [\n                        {\n                            "display_url": "twitter.com/i/web/status/1…",\n                            "expanded_url": "https://twitter.com/i/web/status/1192197028559937544",\n                            "indices": [\n                                117,\n                                140\n                            ],\n                            "url": "https://t.co/4AfTqVPVRq"\n                        }\n                    ],\n                    "user_mentions": []\n                },\n                "favorite_count": 86,\n                "favorited": false,\n                "geo": null,\n                "id": 1192197028559937544,\n                "id_str": "1192197028559937544",\n                "in_reply_to_screen_name": null,\n                "in_reply_to_status_id": null,\n                "in_reply_to_status_id_str": null,\n                "in_reply_to_user_id": null,\n                "in_reply_to_user_id_str": null,\n                "is_quote_status": false,\n                "lang": "es",\n                "place": null,\n                "possibly_sensitive": false,\n                "possibly_sensitive_appealable": false,\n                "retweet_count": 18,\n                "retweeted": false,\n                "source": "<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>",\n                "text": "Larga vida al bolón mixto de maduro de Tere. En la vida siempre están los que se quedan criticando y los que dan el… https://t.co/4AfTqVPVRq",\n                "truncated": true,\n                "user": {\n                    "can_media_tag": true,\n                    "contributors_enabled": false,\n                    "created_at": "Tue May 25 20:13:42 +0000 2010",\n                    "default_profile": false,\n                    "default_profile_image": false,\n                    "description": "Periodista Deportivo: Fanático Ecuadortv, @f_sin_cassette , ”Al Toque” Radio Caravana, “Minuto Cero” Diblu, DT infanto juvenil @campusatfa, árbitro (2017)",\n                    "entities": {\n                        "description": {\n                            "urls": []\n                        },\n                        "url": {\n                            "urls": [\n                                {\n                                    "display_url": "youtu.be/6PnBIHvHd-8",\n                      ...

# %%
#@title How can we extract the keys we need from the dictionary?
# "id", "user", "mentions", "count_mentions", "favourites_count", "followers_count", "friends_count", "location", "place", "text", "is_respuesta", "id_tweet_origen", "user_tweet_origen"
"""
"id"                -> data["id"]
"user"              -> data["user"]["screen_name"]
"mentions"          -> [account["screen_name"] for account in data["entities"]["user_mentions"]]
"count_mentions"    -> len(mentions)
"favourites_count"  -> data["user"]["favourites_count"]
"followers_count"   -> data["user"]["followers_count"]
"friends_count"     -> data["user"]["friends_count"]
"location"          -> data["user"]["location"]
"place"             -> data["place"]
"text"              -> data["text"]
"is_respuesta"      -> data["retweeted_status"]
                    is_respuesta = None
                    try:
                        data["retweeted_status"]
                        is_respuesta = True
                    except:
                        is_respuesta = False
"id_tweet_origen"   -> data["retweeted_status"]["id"]
"user_tweet_origen" -> data["retweeted_status"]["user"]["screen_name"]
"""
# Out:
# '\n"id"                -> data["id"]\n"user"              -> data["user"]["screen_name"]\n"mentions"          -> [account["screen_name"] for account in data["entities"]["user_mentions"]]\n"count_mentions"    -> len(mentions)\n"favourites_count"  -> data["user"]["favourites_count"]\n"followers_count"   -> data["user"]["followers_count"]\n"friends_count"     -> data["user"]["friends_count"]\n"location"          -> data["user"]["location"]\n"place"             -> data["place"]\n"text"              -> data["text"]\n"is_respuesta"      -> data["retweeted_status"]\n                    is_respuesta = None\n                    try:\n                        data["retweeted_status"]\n                        is_respuesta = True\n                    except:\n                        is_respuesta = False\n"id_tweet_origen"   -> data["retweeted_status"]["id"]\n"user_tweet_origen" -> data["retweeted_status"]["user"]["screen_name"]\n'

# %% [markdown]
# ## Generar CSV

# %%
#@title Create DataFrame
from tqdm.auto import tqdm

diccionario = {
    "id": [],
    "user": [],
    "mentions": [],
    "count_mentions": [],
    "favourites_count": [],
    "followers_count": [],
    "friends_count": [],
    "location": [],
    "place": [],
    "text": [],
    "is_respuesta": [],
    "id_tweet_origen": [],
    "user_tweet_origen": []
}

for tweet in tqdm(data['tweets']):
    diccionario["id"].append(tweet["id"])
    diccionario["user"].append(tweet["user"]["screen_name"])
    mentions = [account["screen_name"] for account in tweet["entities"]["user_mentions"]]
    diccionario["mentions"].append(mentions)
    diccionario["count_mentions"].append(len(mentions))
    diccionario["favourites_count"].append(tweet["user"]["favourites_count"])
    diccionario["followers_count"].append(tweet["user"]["followers_count"])
    diccionario["friends_count"].append(tweet["user"]["friends_count"])
    diccionario["location"].append(tweet["user"]["location"])
    diccionario["place"].append(tweet["place"])
    diccionario["text"].append(tweet["text"])
    is_respuesta = None
    try:
        tweet["retweeted_status"] # si es el tweet original esta key no existe y
                                  # saltará error llevándonos al except
        diccionario["is_respuesta"].append(True)
        diccionario["id_tweet_origen"].append(tweet["retweeted_status"]["id"])
        diccionario["user_tweet_origen"].append(tweet["retweeted_status"]["user"]["screen_name"])
    except:
        diccionario["is_respuesta"].append(False)
        diccionario["id_tweet_origen"].append(None)
        diccionario["user_tweet_origen"].append(None)

df = pd.DataFrame(diccionario)
display(
    df.info(),
    df.head()
)
# Out:
#   0%|          | 0/4014 [00:00<?, ?it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4014 non-null   int64
#  1   user               4014 non-null   object
#  2   mentions           4014 non-null   object
#  3   count_mentions     4014 non-null   int64
#  4   favourites_count   4014 non-null   int64
#  5   followers_count    4014 non-null   int64
#  6   friends_count      4014 non-null   int64
#  7   location           4014 non-null   object
#  8   place              75 non-null     object
#  9   text               4014 non-null   object
#  10  is_respuesta       4014 non-null   bool
#  11  id_tweet_origen    3061 non-null   float64
#  12  user_tweet_origen  3061 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(6)
# memory usage: 380.4+ KB
# None
#                     id             user                          mentions  \
# 0  1192602342434234371     cesar_jurado                  [joacosaavedraq]
# 1  1192600432020996097    donoso_molina  [FranFerreroMD, fraguaciudadana]
# 2  1192593176378445826        LexyLucin                   [Belliiisima89]
# 3  1192585514941112326           Cjvs12                     [Mano_Hostil]
# 4  1192583767489204225  DrStrangGuayaco                                []
#
#    count_mentions  favourites_count  followers_count  friends_count  \
# 0               1              1512              224            397
# 1               2                38               37             28
# 2               1                41                5            119
# 3               1              1556               32            532
# 4               0              4008             5978           1780
#
#              location                                              place  \
# 0           Guayaquil                                               None
# 1     Guayas, Ecuador  {'attributes': {}, 'bounding_box': {'coordinat...
# 2                                                                   None
# 3  Guayaquil, Ecuador                                               None
# 4         MultiVersos                                               None
#
#                                                 text  is_respuesta  \
# 0  RT @joacosaavedraq: Larga vida al bolón mixto ...          True
# 1  @FranFerreroMD @fraguaciudadana Buenas, estima...         False
# 2  RT @Belliiisima89: En el Pais de Alvarito, el ...          True
# 3  RT @Mano_Hostil: Desde la mañana los veo publi...          True
# 4  La verdad hasta ahora no entiendo la joda con ...         False
#
#    id_tweet_origen user_tweet_origen
# 0     1.192197e+18    joacosaavedraq
# 1              NaN              None
# 2     1.192188e+18     Belliiisima89
# 3     1.192533e+18       Mano_Hostil
# 4              NaN              None

# %% [markdown]
# ### Start the process

# %%
# !pip install Unidecode
# !pip install stanza
# Out:
# Collecting Unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 12.4 MB/s eta 0:00:00
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.4.0
# Collecting stanza
#   Downloading stanza-1.11.1-py3-none-any.whl.metadata (14 kB)
# Collecting emoji (from stanza)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from stanza) (2.0.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from stanza) (4.9.4)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (5.29.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from stanza) (2.32.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from stanza) (3.6.1)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from stanza) (2.10.0+cpu)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stanza) (4.67.3)
# Collecting udtools>=0.2.4 (from stanza)
#   Downloading udtools-0.2.7-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->stanza) (2025.3.0)
# Collecting udapi>=0.5.0 (from udtools>=0.2.4->stanza)
#   Downloading udapi-0.5.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: regex>=2020.09.27 in /usr/local/lib/python3.12/dist-packages (from udtools>=0.2.4->stanza) (2025.11.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->stanza) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->stanza) (1.3.0)
# Collecting colorama (from udapi>=0.5.0->udtools>=0.2.4->stanza)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from udapi>=0.5.0->udtools>=0.2.4->stanza) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->stanza) (3.0.3)
# Downloading stanza-1.11.1-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.5 MB/s eta 0:00:00
# Downloading udtools-0.2.7-py3-none-any.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.7/773.7 kB 34.7 MB/s eta 0:00:00
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 33.6 MB/s eta 0:00:00
# Downloading udapi-0.5.2-py3-none-any.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.7/418.7 kB 24.7 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: emoji, colorama, udapi, udtools, stanza
# Successfully installed colorama-0.4.6 emoji-2.15.0 stanza-1.11.1 udapi-0.5.2 udtools-0.2.7

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt') # sirve para poder quitar los signos de puntuación
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import stanza
stanza.download("es")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/resources.json
# INFO:stanza:Downloading default packages for language: es (Spanish) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.11.0/models/default.zip:   0%|          | …
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/es/default.zip
# INFO:stanza:Finished downloading models and saved to /root/.cache/stanza/1.11.0/resources
# [['zip', 'default.zip']]

# %%
from nltk import SpaceTokenizer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from unidecode import unidecode
import re

def simple_filter(single_tweet):
    """
    `SpaceTokenizer` practicamente le hace un split al texto
    """
    tokens = SpaceTokenizer().tokenize(single_tweet)
    tokens_filtered = [token for token in tokens if len(token)>1]
    text_filtered = " ".join(str(x) for x in tokens_filtered)
    return text_filtered

def process_text(text):
    text = text.lower()
    text = re.sub(r"(https?)\S+","",text) # remove urls
    text = re.sub(r"(\B#)\w*","",text) # remove hashtags
    text = re.sub(r"(\B@)\w*","",text) # remove mentions
    text = re.sub("\n","",text) # remove lines separate
    return text

tokenizer = RegexpTokenizer(r'\w+')
def remove_punctuation(text):
    local_tokens = tokenizer.tokenize(text)
    return " ".join(local_tokens)

stop_words_list = stopwords.words('spanish')
stop_words_list.append("si")
def remove_stopwords(text):
    language = 'spanish'
    stop_words = set(stopwords.words(language))
    return ' '.join([word for word in text.split() if word.lower() not in stop_words_list])

def remove_accents(text):
    if isinstance(text, str):
        return unidecode(text)
    return text

def delete_RT(text):
    text = text[3:] if text.lower().startswith("rt ") else text
    return text

nlp = stanza.Pipeline(lang='es', processors='tokenize,mwt,pos,lemma')
def apply_lemmatization(text):
    doc = nlp(text)
    lemmas = []
    for sent in doc.sentences:
        for token in sent.words:
            lemmas.append(token.lemma)
    return " ".join(lemmas)

def all_preprocess(text):
    text = simple_filter(text)
    text = process_text(text)
    text = remove_punctuation(text)
    text = remove_stopwords(text)
    text = remove_accents(text)
    text = delete_RT(text)
    text = apply_lemmatization(text)
    return text
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json:   0%|  …
# INFO:stanza:Downloaded file to /root/.cache/stanza/1.11.0/resources/resources.json
# INFO:stanza:Loading these models for language: es (Spanish):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | mwt       | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!

# %%
df["text_processed"] = df.loc[:, "text"].apply(all_preprocess)
df["text_processed"]
# Out:
# 0       largo vida bolon mixto maduro tere vida siempr...
# 1       buen estimar creer nacimiento bolon tere remon...
# 2       país alvarito bolon tere ir aceptar tarjeta cr...
# 3       manana ver publicar foto ewan gye cada foto me...
# 4       verdad ahora entender jodar bolon tere decir p...
#                               ...
# 4009    nunca comer leer acomplejado quejar él exito s...
# 4010    nunca comer leer acomplejado quejar él exito s...
# 4011                             pues detractor fiel acar
# 4012         buen bolón calidad siempre ir costar persona
# 4013    uds comen bolon hahahhaha mejor olvdes salsa a...
# Name: text_processed, Length: 4014, dtype: object

# %%
df[df.text_processed.isna()]
# Out:
# Empty DataFrame
# Columns: [id, user, mentions, count_mentions, favourites_count, followers_count, friends_count, location, place, text, is_respuesta, id_tweet_origen, user_tweet_origen, text_processed]
# Index: []

# %%
# Eliminar tweets que solo tenían menciones y emojis

df = df.dropna(subset=['text_processed'])

# %% [markdown]
# ### Visualization of the cloud

# %%
# Fución para hacer el word cloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

def plot_word_cloud(text, title=None, background_color="black"):
    # Generar el word cloud
    #wordcloud = WordCloud(stopwords=STOPWORDS, background_color="white").generate(text)
    wordcloud = WordCloud(background_color=background_color).generate(text)

    # Crear Figura
    plt.figure(figsize=(10, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    if title is not None:
        plt.title(title)
    plt.show()

# %%
text = " ".join(df.text_processed)
plot_word_cloud(text)

# %% [markdown]
# ### Saving CSV

# %%
df.to_csv(source_path + "cafe_de_tere_flattened.csv")

# %% [markdown]
# # Answering questions

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm

# %% [markdown]
# ## Load CSV

# %%
df = pd.read_csv(source_path + "cafe_de_tere_flattened.csv")
display(
    df.info(),
    df.head()
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4014 entries, 0 to 4013
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4014 non-null   int64
#  1   id                 4014 non-null   int64
#  2   user               4014 non-null   object
#  3   mentions           4014 non-null   object
#  4   count_mentions     4014 non-null   int64
#  5   favourites_count   4014 non-null   int64
#  6   followers_count    4014 non-null   int64
#  7   friends_count      4014 non-null   int64
#  8   location           2902 non-null   object
#  9   place              75 non-null     object
#  10  text               4014 non-null   object
#  11  is_respuesta       4014 non-null   bool
#  12  id_tweet_origen    3061 non-null   float64
#  13  user_tweet_origen  3061 non-null   object
#  14  text_processed     4006 non-null   object
# dtypes: bool(1), float64(1), int64(6), object(7)
# memory usage: 443.1+ KB
# None
#    Unnamed: 0                   id             user  \
# 0           0  1192602342434234371     cesar_jurado
# 1           1  1192600432020996097    donoso_molina
# 2           2  1192593176378445826        LexyLucin
# 3           3  1192585514941112326           Cjvs12
# 4           4  1192583767489204225  DrStrangGuayaco
#
#                                mentions  count_mentions  favourites_count  \
# 0                    ['joacosaavedraq']               1              1512
# 1  ['FranFerreroMD', 'fraguaciudadana']               2                38
# 2                     ['Belliiisima89']               1                41
# 3                       ['Mano_Hostil']               1              1556
# 4                                    []               0              4008
#
#    followers_count  friends_count            location  \
# 0              224            397           Guayaquil
# 1               37             28     Guayas, Ecuador
# 2                5            119                 NaN
# 3               32            532  Guayaquil, Ecuador
# 4             5978           1780         MultiVersos
#
#                                                place  \
# 0                                                NaN
# 1  {'attributes': {}, 'bounding_box': {'coordinat...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 text  is_respuesta  \
# 0  RT @joacosaavedraq: Larga vida al bolón mixto ...          True
# 1  @FranFerreroMD @fraguaciudadana Buenas, estima...         False
# 2  RT @Belliiisima89: En el Pais de Alvarito, el ...          True
# 3  RT @Mano_Hostil: Desde la mañana los veo publi...          True
# 4  La verdad hasta ahora no entiendo la joda con ...         False
#
#    id_tweet_origen user_tweet_origen  \
# 0     1.192197e+18    joacosaavedraq
# 1              NaN               NaN
# 2     1.192188e+18     Belliiisima89
# 3     1.192533e+18       Mano_Hostil
# 4              NaN               NaN
#
#                                       text_processed
# 0  largo vida bolon mixto maduro tere vida siempr...
# 1  buen estimar creer nacimiento bolon tere remon...
# 2  país alvarito bolon tere ir aceptar tarjeta cr...
# 3  manana ver publicar foto ewan gye cada foto me...
# 4  verdad ahora entender jodar bolon tere decir p...

# %% [markdown]
# ## Question 1: I would like to know which are the 10 most popular tweets (the ones with the most likes or retweets).

# %%
df[df.count_mentions>1].id.unique()
# []

# %%
# prompt: Haz un hbar plot con el top de "favourites_count" del dataframe df_p1. Hazlo coloreando las barras en un gradiente secuencial en donde el top 1 sea dorado intenso y el top 10 sea un dorado más suave (un poco más blanco)

import matplotlib.pyplot as plt
import seaborn as sns

# Create the hbar plot with seaborn
sns.set_theme(style="whitegrid")
ax = sns.barplot(
    data=df_p1.head(10),
    x="favourites_count",
    y="user",
    palette="YlOrBr_r",
    orient="h",
)

# Set the title and labels
ax.set_title("Top 10 Tweets por conteo de ♥ Favoritos", fontdict={"size": 16})
ax.set_xlabel("Favourites Count", fontdict={"size": 14})
ax.set_ylabel("User", fontdict={"size": 14})

# Adjust the spacing between the bars
ax.bar_label(ax.containers[0])
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1975/2938146011.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# ## Question 2: What are people saying about my brand?

# %%
# Elimina todos los registros que en df, en su columna text_processed, tengan Nulo

df = df.dropna(subset=['text_processed'])

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

def plot_word_cloud(text, title=None, background_color="black"):
    # Generar el word cloud
    #wordcloud = WordCloud(stopwords=STOPWORDS, background_color="white").generate(text)
    wordcloud = WordCloud(background_color=background_color, collocations=False, stopwords=['rt']).generate(text)

    # Crear Figura
    plt.figure(figsize=(10, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    if title is not None:
        plt.title(title)
    plt.show()

# %%
text = " ".join(df.text_processed)
plot_word_cloud(text)

# %% [markdown]
# ### Colocaciones

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import collections
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
all_tokens = []
for single_tweet in df.loc[:, "text_processed"].values:
    tokens = word_tokenize(single_tweet)
    all_tokens += tokens
counter = collections.Counter(all_tokens)
print(counter)
# Out:
# Counter({'tere': 3372, 'cafe': 2627, 'bolon': 2092, 'exito': 1003, 'duen': 989, 'hoy': 840, 'aquí': 832, 'teresa': 805, 'primero': 801, 'castro': 789, 'vendio': 787, 'they': 787, 'vecino': 786, 'mendoza': 785, 'querer': 712, 'él': 503, 'buen': 502, 'hacer': 448, 'buscar': 446, 'tema': 445, 'comer': 427, 'sobrevalorado': 415, 'opinión': 402, 'sufrir': 395, 'coma': 385, 'chucha': 383, 'oficio': 383, 'recomendación': 382, 'bien': 271, 'ser': 256, 'gustar': 245, 'ir': 243, 'pagar': 240, '5': 231, 'cobrar': 227, 'nunca': 224, 'parecer': 212, 'desayuno': 206, 'quejar': 205, 'deber': 204, 'leer': 204, 'seguro': 193, 'acomplejado': 190, 'caro': 189, 'dar': 177, 'poder': 175, 'ahora': 155, 'madre': 152, 'sazon': 136, 'sólo': 133, 'mejor': 127, 'ahí': 127, 'rico': 124, 'madrina': 121, 'día': 120, 'agachadito': 119, 'ecuatoriano': 117, 'hilo': 110, 'jus': 110, 'criticar': 108, 'trabajar': 108, 'malo': 108, 'bolón': 106, 'odio': 105, 'hablar': 105, 'pasar': 104, 'exitoso': 104, 'dejar': 100, 'verde': 99, 'senora': 96, 'recordar': 91, 'abrir': 90, 'decir': 84, 'contar': 84, 'chica': 83, 'choza': 82, 'terreno': 82, 'garzoto': 82, 'tiempo': 82, 'reventar': 81, 'duro': 81, 'chicharron': 81, 'serio': 80, 'encantar': 79, 'puro': 78, 'odiar': 77, 'tigrillo': 76, 'ver': 74, 'necesidad': 74, 'país':
# %% [markdown]
# #### Bigrams

# %% [markdown]
# ##### Create Data

# %%
def get_bigrams_info(window_size, score_method=None):
    print('Inicializando...', end='')
    bigrams = nltk.collocations.BigramAssocMeasures()
    bigramFinder = nltk.collocations.BigramCollocationFinder\
                                    .from_words(all_tokens,
                                                window_size=window_size
                                                )
    print('\r', end='')
    print('Scoring Bigrams...', end='')
    r_bigrams = list(bigramFinder.score_ngrams(
        # este es el método de cálculo
        bigrams.raw_freq if score_method is None else score_method
        #otros métodos por ejemplo:
        #bigrams.chi_sq
        # los otros métodos suelen funcionar mejor con más datos
        )
    )
    r_bigrams = sorted(r_bigrams, key=lambda tup: tup[1], reverse=True)
    r_bigrams_scored = r_bigrams[0:50]
    best_ngrams = list(bigramFinder.nbest(bigrams.raw_freq, 50))

    ctn = np.array([score for _,score in r_bigrams_scored]).sum()
    print('\r', end='')
    words, scores, percents = [], [], []
    for (x,y),score in tqdm(r_bigrams_scored, desc='Guardando'):
        words.append(x + " - " + y)
        scores.append(score)
        percents.append(round(100*score/ctn, 1))

    return words, scores, percents

# %%
# Crea un dataframe de bigrams

df_bigrams = pd.DataFrame()
for i in tqdm(range(3, 9)):
  words, scores, percents = get_bigrams_info(i)
  df_bigrams[f"words_{i}"] = words
  df_bigrams[f"scores_{i}"] = scores
  df_bigrams[f"percents_{i}"] = percents

display(df_bigrams)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Guardando:   0%|          | 0/50 [00:00<?, ?it/s]
# Guardando:   0%|          | 0/50 [00:00<?, ?it/s]
# Guardando:   0%|          | 0/50 [00:00<?, ?it/s]
# Guardando:   0%|          | 0/50 [00:00<?, ?it/s]
# Guardando:   0%|          | 0/50 [00:00<?, ?it/s]
# Guardando:   0%|          | 0/50 [00:00<?, ?it/s]
#                           words_3  scores_3  percents_3               words_4  \
# 0                     cafe - tere  0.028975         8.1           cafe - tere
# 1                      hoy - cafe  0.009216         2.6            hoy - tere
# 2                     tere - aquí  0.008989         2.5            hoy - cafe
# 3                     duen - cafe  0.008955         2.5          cafe - exito
# 4                     duen - tere  0.008955         2.5           tere - aquí
# 5                     cafe - aquí  0.008943         2.5           cafe - aquí
# 6                 teresa - castro  0.008943         2.5           duen - cafe
# 7                    aquí - exito  0.008909         2.5           duen - tere
# 8                     bolon - hoy  0.008909         2.5       teresa - castro
# 9                  bolon - vecino  0.008909         2.5          tere - exito
# 10               castro - mendoza  0.008909         2.5          aquí - exito
# 11                castro - vendio  0.008909         2.5          bolon - duen
# 12                     hoy - duen  0.008909         2.5           bolon - hoy
# 13              mendoza - primero  0.008909         2.5        bolon - vecino
# 14               mendoza - vendio  0.008909         2.5      castro - mendoza
# 15                primero - bolon  0.008909         2.5      castro - primero
# 16               primero - vecino  0.008909         2.5       castro - vendio
# 17                   tere - exito  0.008909         2.5           duen - aquí
# 18               teresa - mendoza  0.008909         2.5            hoy - duen
# 19                  vecino - duen  0.008909         2.5       mendoza - bolon
# 20                   vecino - hoy  0.008909         2.5     mendoza - primero
# 21                 vendio - bolon  0.008909         2.5      mendoza - vendio
# 22               vendio - primero  0.008909         2.5       primero - bolon
# 23                    aquí - they  0.008887         2.5         primero - hoy
# 24                   exito - they  0.008887         2.5      primero - vecino
# 25                   bolon - tere  0.007933         2.2      teresa - mendoza
# 26                 exito - teresa  0.005902         1.6       teresa - vendio
# 27                  they - teresa  0.005890         1.6         vecino - cafe
# 28                  they - castro  0.005879         1.6         vecino - duen
# 29           tere - sobrevalorado  0.004472         1.2          vecino - hoy
# 30                    tema - cafe  0.004449         1.2        vendio - bolon
# 31                    tema - tere  0.004438         1.2      vendio - primero
# 32                 tere - opinión  0.004370         1.2       vendio - vecino
# 33                 cafe - opinión  0.004358         1.2           aquí - they
# 34                  coma - querer  0.004347         1.2          exito - they
# 35                buscar - oficio  0.004335         1.2           tere - they
# 36                chucha - buscar  0.004324         1.2          bolon - tere
# 37                chucha - querer  0.004324         1.2        exito - teresa
# 38                  coma - chucha  0.004324         1.2         aquí - teresa
# 39        opinión - recomendación  0.004324         1.2        exito - castro
# 40        opinión - sobrevalorado  0.004324         1.2         they - teresa
# 41                querer - buscar  0.004324         1.2         they - castro
# 42                querer - oficio  0.004324         1.2        they - mendoza
# 43           recomendación - coma  0.004324         1.2           tema - tere
# 44         recomendación - sufrir  0.004324         1.2  tere - sobrevalorado
# 45  sobrevalorado - recomendación  0.004324         1.2           tema - cafe
# 46         sobrevalorado - sufrir  0.004324         1.2  cafe - sobrevalorado
# 47                sufrir - chucha  0.004324         1.2        tere - opinión
# 48                  sufrir - coma  0.004324         1.2        cafe - opinión
# 49                    tere - bien  0.002690         0.8         coma - querer
#
#     scores_4  percents_4            words_5  scores_5  percents_5  \
# 0   0.019430         7.0        cafe - tere  0.014794         6.4
# 1   0.006159         2.2       bolon - cafe  0.005697         2.5
# 2   0.006151         2.2       bolon - tere  0.004818         2.1
# 3   0.006091         2.2         hoy - cafe  0.004631         2.0
# 4   0.006030         2.2         hoy - tere  0.004625         2.0
# 5   0.005977         2.1       cafe - exito  0.004568         2.0
# 6   0.005970         2.1        tere - aquí  0.004540         2.0
# 7   0.005970         2.1        cafe - aquí  0.004506         1.9
# 8   0.005962         2.1        duen - cafe  0.004483         1.9
# 9   0.005947         2.1        duen - tere  0.004477         1.9
# 10  0.005940         2.1    teresa - castro  0.004472         1.9
# 11  0.005940         2.1    primero - bolon  0.004460         1.9
# 12  0.005940         2.1       tere - exito  0.004460         1.9
# 13  0.005940         2.1       aquí - exito  0.004455         1.9
# 14  0.005940         2.1       bolon - duen  0.004455         1.9
# 15  0.005940         2.1        bolon - hoy  0.004455         1.9
# 16  0.005940         2.1     bolon - vecino  0.004455         1.9
# 17  0.005940         2.1     castro - bolon  0.004455         1.9
# 18  0.005940         2.1   castro - mendoza  0.004455         1.9
# 19  0.005940         2.1   castro - primero  0.004455         1.9
# 20  0.005940         2.1    castro - vendio  0.004455         1.9
# 21  0.005940         2.1        duen - aquí  0.004455         1.9
# 22  0.005940         2.1       duen - exito  0.004455         1.9
# 23  0.005940         2.1         hoy - aquí  0.004455         1.9
# 24  0.005940         2.1         hoy - duen  0.004455         1.9
# 25  0.005940         2.1    mendoza - bolon  0.004455         1.9
# 26  0.005940         2.1  mendoza - primero  0.004455         1.9
# 27  0.005940         2.1   mendoza - vecino  0.004455         1.9
# 28  0.005940         2.1   mendoza - vendio  0.004455         1.9
# 29  0.005940         2.1     primero - duen  0.004455         1.9
# 30  0.005940         2.1      primero - hoy  0.004455         1.9
# 31  0.005940         2.1   primero - vecino  0.004455         1.9
# 32  0.005940         2.1   teresa - mendoza  0.004455         1.9
# 33  0.005924         2.1   teresa - primero  0.004455         1.9
# 34  0.005924         2.1    teresa - vendio  0.004455         1.9
# 35  0.005924         2.1      vecino - cafe  0.004455         1.9
# 36  0.005894         2.1      vecino - duen  0.004455         1.9
# 37  0.003950         1.4       vecino - hoy  0.004455         1.9
# 38  0.003934         1.4      vecino - tere  0.004455         1.9
# 39  0.003934         1.4     vendio - bolon  0.004455         1.9
# 40  0.003927         1.4       vendio - hoy  0.004455         1.9
# 41  0.003919         1.4   vendio - primero  0.004455         1.9
# 42  0.003919         1.4    vendio - vecino  0.004455         1.9
# 43  0.003004         1.1        aquí - they  0.004443         1.9
# 44  0.003004         1.1        cafe - they  0.004443         1.9
# 45  0.002989         1.1       exito - they  0.004443         1.9
# 46  0.002974         1.1        tere - they  0.004443         1.9
# 47  0.002943         1.1      tere - teresa  0.003303         1.4
# 48  0.002913         1.0     exito - teresa  0.002962         1.3
# 49  0.002898         1.0      aquí - teresa  0.002957         1.3
#
#               words_6  scores_6  percents_6            words_7  scores_7  \
# 0         cafe - tere  0.012039         6.2        cafe - tere  0.010525
# 1        bolon - tere  0.007954         4.1       bolon - tere  0.006938
# 2        bolon - cafe  0.004708         2.4       bolon - cafe  0.004078
# 3          hoy - cafe  0.003714         1.9        duen - cafe  0.003238
# 4          hoy - tere  0.003714         1.9         hoy - tere  0.003102
# 5         duen - cafe  0.003682         1.9         hoy - cafe  0.003098
# 6        cafe - exito  0.003655         1.9        duen - tere  0.003076
# 7      teresa - bolon  0.003641         1.9       cafe - exito  0.003045
# 8         tere - aquí  0.003636         1.9        tere - aquí  0.003045
# 9         cafe - aquí  0.003618         1.9     teresa - bolon  0.003034
# 10        duen - tere  0.003586         1.9        cafe - aquí  0.003015
# 11     primero - cafe  0.003586         1.9       bolon - aquí  0.003000
# 12    teresa - castro  0.003577         1.9     primero - cafe  0.002992
# 13    primero - bolon  0.003573         1.9     primero - tere  0.002992
# 14       tere - exito  0.003573         1.9    teresa - castro  0.002981
# 15       aquí - exito  0.003564         1.8    primero - bolon  0.002977
# 16       bolon - duen  0.003564         1.8       tere - exito  0.002977
# 17        bolon - hoy  0.003564         1.8        duen - aquí  0.002974
# 18     bolon - vecino  0.003564         1.8       duen - exito  0.002974
# 19     castro - bolon  0.003564         1.8      vendio - cafe  0.002974
# 20   castro - mendoza  0.003564         1.8       aquí - exito  0.002970
# 21   castro - primero  0.003564         1.8       bolon - duen  0.002970
# 22    castro - vecino  0.003564         1.8        bolon - hoy  0.002970
# 23    castro - vendio  0.003564         1.8     bolon - vecino  0.002970
# 27         1.8     castro - bolon  0.002546         1.8
# 28         1.8      castro - duen  0.002546         1.8
# 29         1.8       castro - hoy  0.002546         1.8
# 30         1.8   castro - mendoza  0.002546         1.8
# 31         1.8   castro - primero  0.002546         1.8
# 32         1.8    castro - vecino  0.002546         1.8
# 33         1.8    castro - vendio  0.002546         1.8
# 34         1.8         hoy - duen  0.002546         1.8
# 35         1.8        hoy - exito  0.002546         1.8
# 36         1.8    mendoza - bolon  0.002546         1.8
# 37         1.8     mendoza - cafe  0.002546         1.8
# 38         1.8     mendoza - duen  0.002546         1.8
# 39         1.8      mendoza - hoy  0.002546         1.8
# 40         1.8  mendoza - primero  0.002546         1.8
# 41         1.8   mendoza - vecino  0.002546         1.8
# 42         1.8   mendoza - vendio  0.002546         1.8
# 43         1.8     primero - aquí  0.002546         1.8
# 44         1.8     primero - duen  0.002546         1.8
# 45         1.8      primero - hoy  0.002546         1.8
# 46         1.8   primero - vecino  0.002546         1.8
# 47         1.8       teresa - hoy  0.002546         1.8
# 48         1.8   teresa - mendoza  0.002546         1.8
# 49         1.8   teresa - primero  0.002546         1.8

# %%
# Save data of bigrams
df_bigrams.to_csv(source_path+'data_bigrams.csv', index=False)

# %% [markdown]
# ##### Visualize Bigrams

# %%
df_bigrams = pd.read_csv(source_path+'data_bigrams.csv')

# %%
# prompt: Grafica 6 subplots (2 columnas y 3 filas) quiero que en cada uno hagas un gráfico de barras con el top 10 colocaciones con más porcentaje. Cada subplot va a tener un gráfico de barras de un window_size. Recuerda que las columnas del dataframe tienen el siguiente formato: words_{i}, scores_{i}, percents_{i}. Haz el gráfico de barras en orden descendente y con 'words_i' en los label del eje y

import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(3, 2, figsize=(18, 12))

for i, ax in enumerate(axes.flat):
    data = df_bigrams.loc[:, df_bigrams.columns[i*3:(i+1)*3]]
    data = data.sort_values(by=f"percents_{i+3}", ascending=False).head(10)
    sns.barplot(data=data,
                ax=ax,
                x=f"percents_{i+3}",
                y=f"words_{i+3}",
                palette="YlOrBr_r"
                )
    ax.set_title(f"Window Size: {i+3}")
    ax.set_xlabel("Percentage")
    #ax.set_ylabel("Words")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1975/2446643770.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2446643770.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2446643770.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2446643770.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2446643770.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2446643770.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,

# %% [markdown]
# #### Trigrams

# %% [markdown]
# ##### Create Data

# %%
def get_trigrams_info(window_size, score_method=None):
    trigrams = nltk.collocations.TrigramAssocMeasures()
    trigramFinder = nltk.collocations.TrigramCollocationFinder\
                                     .from_words(all_tokens,
                                                 window_size=window_size
                                                 )
    print('\r', end='')
    print('Scoring Bigrams...', end='')
    trigrams_scored = list(trigramFinder.score_ngrams(
        trigrams.raw_freq if score_method is None else score_method
        )
    )
    #best_trigrams = list(trigramFinder.nbest(trigrams.raw_freq, 50))
    trigrams_scored = sorted(trigrams_scored, key=lambda tup: tup[1], reverse=True)
    trigrams_scored = trigrams_scored[0:50]

    #ctn = 0
    #for (x,y,z),score in trigrams_scored:
    #    ctn += score
    ctn = np.array([score for _,score in trigrams_scored]).sum()
    print('\r', end='')

    results_trigrams = {}
    words, scores, percents = [], [], []
    for (x,y,z),score in tqdm(trigrams_scored):
        words.append(x + "_" + y + "_" + z)
        scores.append(score)
        percents.append(round(100*score/ctn, 1))

    return words, scores, percents

# %%
# Crea un dataframe de bigrams

df_trigrams = pd.DataFrame()
for i in tqdm(range(4, 10)):
  words, scores, percents = get_trigrams_info(window_size=i)
  df_trigrams[f"words_{i}"] = words
  df_trigrams[f"scores_{i}"] = scores
  df_trigrams[f"percents_{i}"] = percents

display(df_trigrams)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#                        words_4  scores_4  percents_4                 words_5  \
# 0                hoy_cafe_tere  0.006144         2.4           hoy_cafe_tere
# 1               cafe_tere_aquí  0.005970         2.3          cafe_tere_aquí
# 2               duen_cafe_tere  0.005970         2.3          duen_cafe_tere
# 3               bolon_hoy_duen  0.005940         2.3         bolon_duen_cafe
# 4            bolon_vecino_duen  0.005940         2.3          bolon_hoy_cafe
# 5             bolon_vecino_hoy  0.005940         2.3          bolon_hoy_duen
# 6              cafe_aquí_exito  0.005940         2.3       bolon_vecino_cafe
# 7              cafe_tere_exito  0.005940         2.3       bolon_vecino_duen
# 8       castro_mendoza_primero  0.005940         2.3        bolon_vecino_hoy
# 9        castro_mendoza_vendio  0.005940         2.3         cafe_aquí_exito
# 10       castro_vendio_primero  0.005940         2.3         cafe_tere_exito
# 11              duen_cafe_aquí  0.005940         2.3    castro_mendoza_bolon
# 12              duen_tere_aquí  0.005940         2.3  castro_mendoza_primero
# 13               hoy_duen_cafe  0.005940         2.3   castro_mendoza_vendio
# 14               hoy_duen_tere  0.005940         2.3    castro_primero_bolon
# 15       mendoza_primero_bolon  0.005940         2.3     castro_vendio_bolon
# 16        mendoza_vendio_bolon  0.005940         2.3   castro_vendio_primero
# 17      mendoza_vendio_primero  0.005940         2.3         duen_aquí_exito
# 18           primero_bolon_hoy  0.005940         2.3          duen_cafe_aquí
# 19        primero_bolon_vecino  0.005940         2.3         duen_cafe_exito
# 20          primero_vecino_hoy  0.005940         2.3          duen_tere_aquí
# 21             tere_aquí_exito  0.005940         2.3         duen_tere_exito
# 22       teresa_castro_mendoza  0.005940         2.3           hoy_cafe_aquí
# 23        teresa_castro_vendio  0.005940         2.3           hoy_duen_aquí
# 24       teresa_mendoza_vendio  0.005940         2.3           hoy_duen_cafe
# 25            vecino_duen_cafe  0.005940         2.3           hoy_duen_tere
# 26             vecino_hoy_cafe  0.005940         2.3           hoy_tere_aquí
# 27             vecino_hoy_duen  0.005940         2.3    mendoza_bolon_vecino
# 28         vendio_bolon_vecino  0.005940         2.3   mendoza_primero_bolon
# 29        vendio_primero_bolon  0.005940         2.3  mendoza_primero_vecino
# 30       vendio_primero_vecino  0.005940         2.3    mendoza_vendio_bolon
# 31             aquí_exito_they  0.005924         2.3  mendoza_vendio_primero
# 32              tere_aquí_they  0.005924         2.3   mendoza_vendio_vecino
# 33             tere_exito_they  0.005924         2.3      primero_bolon_duen
# 34         exito_teresa_castro  0.003934         1.5       primero_bolon_hoy
# 35           aquí_exito_teresa  0.003927         1.5    primero_bolon_vecino
# 25     castro_bolon_vecino  0.001188         2.0          bolon_hoy_duen
# 26    castro_mendoza_bolon  0.001188         2.0         bolon_hoy_exito
# 27      castro_mendoza_hoy  0.001188         2.0          bolon_hoy_tere
# 28  castro_mendoza_primero  0.001188         2.0       bolon_vecino_aquí
# 29   castro_mendoza_vecino  0.001188         2.0       bolon_vecino_cafe
# 30   castro_mendoza_vendio  0.001188         2.0       bolon_vecino_duen
# 31    castro_primero_bolon  0.001188         2.0      bolon_vecino_exito
# 32      castro_primero_hoy  0.001188         2.0        bolon_vecino_hoy
# 33   castro_primero_vecino  0.001188         2.0       bolon_vecino_tere
# 34       castro_vecino_hoy  0.001188         2.0         cafe_aquí_exito
# 35     castro_vendio_bolon  0.001188         2.0         cafe_tere_exito
# 36       castro_vendio_hoy  0.001188         2.0       castro_bolon_duen
# 37   castro_vendio_primero  0.001188         2.0        castro_bolon_hoy
# 38    castro_vendio_vecino  0.001188         2.0     castro_bolon_vecino
# 39         duen_aquí_exito  0.001188         2.0         castro_hoy_duen
# 40         duen_cafe_exito  0.001188         2.0    castro_mendoza_bolon
# 41         duen_tere_exito  0.001188         2.0     castro_mendoza_duen
# 42          hoy_aquí_exito  0.001188         2.0      castro_mendoza_hoy
# 43           hoy_cafe_aquí  0.001188         2.0  castro_mendoza_primero
# 44          hoy_cafe_exito  0.001188         2.0   castro_mendoza_vecino
# 45           hoy_duen_aquí  0.001188         2.0   castro_mendoza_vendio
# 46           hoy_duen_cafe  0.001188         2.0    castro_primero_bolon
# 47          hoy_duen_exito  0.001188         2.0     castro_primero_duen
# 48           hoy_duen_tere  0.001188         2.0      castro_primero_hoy
# 49           hoy_tere_aquí  0.001188         2.0   castro_primero_vecino
#
#     scores_8  percents_8              words_9  scores_9  percents_9
# 0   0.001163         2.7      bolon_cafe_tere  0.000909         2.8
# 1   0.000981         2.3       duen_cafe_tere  0.000803         2.5
# 2   0.000886         2.1        hoy_cafe_tere  0.000730         2.2
# 3   0.000874         2.0        hoy_duen_tere  0.000677         2.1
# 4   0.000864         2.0        hoy_duen_cafe  0.000672         2.1
# 5   0.000855         2.0     bolon_vecino_hoy  0.000667         2.1
# 6   0.000854         2.0     vecino_duen_cafe  0.000656         2.0
# 7   0.000850         2.0      vecino_hoy_cafe  0.000656         2.0
# 8   0.000850         2.0       cafe_tere_aquí  0.000649         2.0
# 9   0.000850         2.0    primero_cafe_tere  0.000643         2.0
# 10  0.000850         2.0      bolon_tere_aquí  0.000642         2.0
# 11  0.000850         2.0   primero_bolon_tere  0.000638         2.0
# 12  0.000850         2.0      bolon_cafe_aquí  0.000637         2.0
# 13  0.000850         2.0     bolon_tere_exito  0.000637         2.0
# 14  0.000850         2.0       duen_cafe_aquí  0.000637         2.0
# 15  0.000850         2.0       duen_tere_aquí  0.000637         2.0
# 16  0.000850         2.0        hoy_cafe_aquí  0.000637         2.0
# 17  0.000849         2.0        hoy_duen_aquí  0.000637         2.0
# 18  0.000849         2.0        hoy_tere_aquí  0.000637         2.0
# 19  0.000849         2.0   primero_bolon_cafe  0.000637         2.0
# 20  0.000849         2.0     vecino_cafe_aquí  0.000637         2.0
# 21  0.000849         2.0     vecino_duen_aquí  0.000637         2.0
# 22  0.000849         2.0      vecino_hoy_aquí  0.000637         2.0
# 23  0.000849         2.0     vecino_tere_aquí  0.000637         2.0
# 24  0.000849         2.0     vendio_cafe_tere  0.000637         2.0
# 25  0.000849         2.0     bolon_aquí_exito  0.000636         2.0
# 26  0.000849         2.0     bolon_cafe_exito  0.000636         2.0
# 27  0.000849         2.0      bolon_duen_aquí  0.000636         2.0
# 28  0.000849         2.0      bolon_duen_cafe  0.000636         2.0
# 29  0.000849         2.0     bolon_duen_exito  0.000636         2.0
# 30  0.000849         2.0      bolon_duen_tere  0.000636         2.0
# 31  0.000849         2.0       bolon_hoy_aquí  0.000636         2.0
# 32  0.000849         2.0       bolon_hoy_cafe  0.000636         2.0
# 33  0.000849         2.0       bolon_hoy_duen  0.000636         2.0
# 34  0.000849         2.0      bolon_hoy_exito  0.000636         2.0
# 35  0.000849         2.0       bolon_hoy_tere  0.000636         2.0
# 36  0.000849         2.0    bolon_vecino_aquí  0.000636         2.0
# 37  0.000849         2.0    bolon_vecino_cafe  0.000636         2.0
# 38  0.000849         2.0    bolon_vecino_duen  0.000636         2.0
# 39  0.000849         2.0   bolon_vecino_exito  0.000636         2.0
# 40  0.000849         2.0    bolon_vecino_tere  0.000636         2.0
# 41  0.000849         2.0      cafe_aquí_exito  0.000636         2.0
# 42  0.000849         2.0      cafe_tere_exito  0.000636         2.0
# 43  0.000849         2.0    castro_bolon_cafe  0.000636         2.0
# 44  0.000849         2.0    castro_bolon_duen  0.000636         2.0
# 45  0.000849         2.0     castro_bolon_hoy  0.000636         2.0
# 46  0.000849         2.0  castro_bolon_vecino  0.000636         2.0
# 47  0.000849         2.0     castro_duen_cafe  0.000636         2.0
# 48  0.000849         2.0      castro_hoy_cafe  0.000636         2.0
# 49  0.000849         2.0      castro_hoy_duen  0.000636         2.0

# %%
# Save data of bigrams
df_trigrams.to_csv(source_path+'data_trigrams.csv', index=False)

# %% [markdown]
# ##### Visualize Bigrams

# %%
df_trigrams = pd.read_csv(source_path+'data_trigrams.csv')

# %%
# prompt: Grafica 6 subplots (2 columnas y 3 filas) quiero que en cada uno hagas un gráfico de barras con el top 10 colocaciones con más porcentaje. Cada subplot va a tener un gráfico de barras de un window_size. Recuerda que las columnas del dataframe tienen el siguiente formato: words_{i}, scores_{i}, percents_{i}. Haz el gráfico de barras en orden descendente y con 'words_i' en los label del eje y

import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(3, 2, figsize=(18, 12))

for i, ax in enumerate(axes.flat):
    data = df_trigrams.loc[:, df_trigrams.columns[i*3:(i+1)*3]]
    data = data.sort_values(by=f"percents_{i+4}", ascending=False).head(10)
    sns.barplot(data=data,
                ax=ax,
                x=f"percents_{i+4}",
                y=f"words_{i+4}",
                palette="YlOrBr_r"
                )
    ax.set_title(f"Window Size: {i+4}")
    ax.set_xlabel("Percentage")
    #ax.set_ylabel("Words")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1975/2783480456.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2783480456.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2783480456.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2783480456.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2783480456.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,
# /tmp/ipykernel_1975/2783480456.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,

# %% [markdown]
# # Question 3: What are the most relevant themes in the messages? Is it product quality? Prices? Service? What’s new?

# %%
# Delete all records in df whose text_processed column has a null value.

df = df.dropna(subset=['text_processed'])

# %%
df[['text_processed']].to_csv(source_path + "text_processed.csv", index=False)

# %%
#@title Visualize words in the tweets.
for elem in np.unique(text.split()): print(elem)
# Out:
# 0
# 0000
# 1
# 10
# 100
# 100m
# 11
# 13
# 15
# 17
# 199
# 1ra
# 2
# 20
# 2008
# 2010
# 2011
# 2012
# 2015
# 2018
# 202
# 2020
# 2da
# 3
# 30
# 32
# 366
# 38
# 3ra
# 4
# 45
# 5
# 50
# 500
# 50cafe
# 50el
# 6
# 652635
# 7
# 70juan
# 75
# 8
# 90s
# 98
# a
# aaah
# abajo
# abcdxyz
# abogado
# abogar
# abrio
# abrir
# abuelito
# aburrido
# abusar
# ac
# aca
# acabar
# acar
# aceptación
# aceptar
# acerca
# acercar
# acogedor
# acogida
# acompano
# acomplejado
# acondicionado
# acondicionar
# acordar
# acorde
# acostumbrado
# acotar
# acotaste
# actitud
# acto
# actual
# actualidad
# actualizar
# acuerdo
# acuso
# adelante
# además
# adjetivo
# admirable
# admirar
# admitir
# adorar
# adular
# aerop
# aeropuerto
# afectar
# afrentoso
# afuerar
# agachadito
# agarra
# agarrar
# agora
# agradable
# agree
# agregar
# agua
# ah
# ahhh
# ahor
# ahora
# ahorita
# ahí
# aire
# aish
# aji
# ajicero
# ala
# alado
# alban
# albodega
# alborada
# alborado
# alboroto
# alcanzar
# alegrar
# alejar
# alem
# alg
# alguien
# algunito
# alguno
# alita
# all
# allá
# allí
# almuerzo
# aloha
# alone
# alternat
# alto
# alvarito
# alvesgatito
# alvinegro
# am
# ama
# amable
# amaneci
# amante
# amar
# amarg
# amargado
# amargar
# amargardo
# amasado
# amasar
# ambiente
# ame
# america
# ames
# amiga
# amigo
# amiguito
# amigxs
# amiko
# amistad
# amor
# amorfino
# amork
# amp
# analisis
# andar
# ando
# aninado
# ano
# antojo
# apalanco
# aparecer
# aparte
# apenas
# aplaudir
# apocalipsis
# apocaliptico
# aporte
# apoyar
# aprendistir
# aprovechar
# apuro
# aqu
# aquel
# aquí
# arbol
# arjona
# armado
# army
# aroma
# arr
# arranco
# arrastrar
# arreglar
# arriendo
# arroz
# as
# aseo
# asique
# asistir
# aspiracional
# asqueroso
# asumir
# así
# at
# atacar
# ataque
# atención
# atender
# atendio
# aterrir
# aterrizo
# atocha
# atorar
# atrevido
# atrás
# aun
# aunque
# aurita
# ausentar
# auténtico
# avanzar
# ave
# avenar
# avenida
# averigue
# avianca
# avicola
# avión
# ayer
# ayyyy
# azucar
# b
# bacer
# bajar
# bajito
# bajo
# balon
# banco
# band
# bandeja
# bandejo
# bano
# barato
# barcelono
# barra
# barrio
# basar
# base
# basico
# bastante
# bastar
# basura
# batir
# bebida
# belleza
# bello
# bendición
# bendigar
# berreo
# beso
# best
# bien
# bienvenido
# bistec
# bitch
# bizarro
# bla
# bloqueo
# cual
# cualqu
# cualquiera
# cuando
# cuanto
# cuarto
# cuenca
# cuenta
# cues
# cuestion
# cuestionar
# cuestión
# culeado
# culean
# culiacan
# culinario
# culpa
# culto
# cultura
# currículum
# cuy
# cyrano
# d
# dado
# dahik
# danar
# dano
# dar
# dass
# datafast
# date
# dav
# deaayunar
# debate
# debater
# deber
# deberia
# debilidad
# decia
# decidir
# decir
# decisiar
# dedicado
# defender
# defendido
# defensa
# defer
# defiend
# definitivamente
# dejar
# dejemono
# dejenm
# delante
# delicia
# delicioso
# dema
# demanda
# demandar
# demasiado
# demoslar
# demostrado
# demostrar
# dentro
# departamento
# depender
# derech
# derecho
# desacuerdo
# desayun
# desayunado
# desayunar
# desayune
# desayuno
# descansar
# desconocer
# desconocido
# descubri
# descubrir
# descuento
# desear
# desencanto
# deseo
# desgastar
# desgraciado
# desinforme
# despachar
# desperdicio
# despertado
# despertar
# desprestigiar
# después
# destacar
# destacer
# destilado
# destilar
# destruir
# detectar
# determinar
# detractor
# detrar
# detro
# diagon
# diario
# dicho
# diecisiete
# diego
# dieta
# diferencia
# diferente
# dificilmente
# digno
# dij
# dime
# dinero
# dio
# diosito
# dire
# directo
# diria
# dirijamoslo
# discrepar
# discusión
# discutar
# discutio
# discutir
# disputar
# divagar
# dividido
# do
# doble
# doblegar
# docente
# documental
# dolar
# doler
# dolor
# domicilio
# domingo
# don
# dona
# donde
# dormir
# dos
# dram
# drama
# duda
# dudario
# duel
# duen
# duena
# dur
# duro
# día
# dólar
# e
# ec
# echar
# economico
# economía
# económico
# ecuador
# ecuatoriano
# ediondo
# efectivo
# egoista
# eh
# ej
# ejemplo
# ejs
# el
# elegir
# elevado
# elitista
# ellapero
# embargo
# embarradito
# emelevy
# emigr
# emitir
# emocionar
# emp
# empanada
# empezar
# empezo
# emple
# empleado
# emplear
# empleo
# empre
# empren
# emprend
# emprendedor
# emprendedora
# emprender
# emprendido
# emprendimie
# emprendimien
# emprendimiento
# emprendio
# empresa
# empresarial
# empresario
# encantar
# encanto
# encebollado
# encon
# encontrado
# encontrar
# encuentro
# enem
# enemigo
# energia
# energio
# enfermo
# enfocar
# enfrentar
# enganoso
# ensimismado
# ensinar
# entender
# entenderia
# entendi
# entero
# entonces
# entrad
# entrar
# entretiempo
# entrevis
# entrevista
# entrevistar
# entro
# envid
# envidia
# envidioso
# episodio
# equivalente
# error
# erudito
# escala
# escencia
# escrito
# escuchar
# ese
# esfuerzo
# esme
# esmeraldo
# esmerar
# esmero
# especial
# especialmente
# espectacular
# esperar
# esposa
# esqui
# esquina
# esse
# est
# estar
# estilo
# estimar
# estoma
# estomago
# estrellar
# estudiar
# estudio
# estupido
# etapa
# etcétera
# eu
# everywhere
# evidencio
# evitar
# ewan
# exaaaacto
# excelencia
# excelente
# excesivam
# excesivamente
# exigir
# existir
# exito
# exitoso
# expandio
# expe
# experiencia
# experto
# explicar
# explico
# exportación
# expresion
# expreso
# exquisita
# exquisito
# extranar
# extrano
# extraordinari
# extrar
# ey
# fa
# fac
# faci
# recordar
# recorranseennnn
# recuerdo
# red
# redacao
# redefinido
# reeves
# referencia
# referente
# referir
# reflejo
# reflexionar
# refutar
# regalar
# regalenme
# regalo
# regionalista
# regla
# regresar
# regreso
# regular
# regularmente
# reina
# relación
# relativamente
# relativo
# remontar
# rentable
# rep
# repente
# repetido
# repetir
# replie
# replop
# reportaje
# representar
# repulsivo
# rescatar
# resentid
# resentido
# resentimiento
# resentirse
# reservado
# resolver
# respectivo
# respecto
# respetar
# respeto
# responder
# respuesta
# restaur
# restaurante
# resto
# resultar
# resumen
# resumio
# resumir
# reto
# reunion
# revelar
# revent
# reventar
# reviso
# rey
# rezar
# reír
# rico
# ricuro
# ridiculo
# rincon
# riquisimo
# riquisimoooo
# robar
# robo
# rol
# romper
# rosca
# rrrrrici
# rt
# rumbo
# rumin
# ruminahui
# rumor
# rustico2
# s
# sa
# sab
# saber
# sabia
# sabor
# sabor15
# sabro
# sabroso
# sacar
# saciado
# sagrado
# salado
# salin
# salino
# salir
# salsa
# salsita
# saludo
# salvador
# salvo
# salón
# samborontown
# same
# samsung
# sanduche
# santo
# saquear
# sar
# sarta
# satisfecho
# sauc
# sauces
# sazon
# scorsese
# seco
# secreto
# sector
# sectorante
# seguir
# segundo
# seguramente
# segurisimo
# seguro
# selecao
# seller
# semana
# sen
# send
# senito
# senor
# senora
# senorar
# senoro
# sensación
# sentado
# sentir
# ser
# serie
# serio
# serrano
# serv
# servicio
# servir
# shar
# sharón
# shut
# siem
# siempr
# siempre
# siend
# sier
# sierra
# siguiente
# siii
# silenciar
# similar
# simon
# simple
# simplemente
# simplon
# sino
# sip
# siquiera
# sistema
# sitio
# slogan
# so
# sobrar
# sobrevalorado
# sobrevivir
# socia
# social
# sociedad
# sol
# solaso
# soldado
# soler
# solo
# solvencia
# sonar
# sopudo
# sorprendente
# sorprender
# sorry
# spice
# spot
# sri
# sria
# standar
# star
# steve
# sua
# suarez
# suave
# subar
# subir
# subject
# subsistir
# suceso
# sucia
# sucio
# suculento
# sucursal
# suficiente
# sufr
# sufridor
# sufrimiento
# sufrir
# sufro
# sugeror
# sumar
# sumelar
# super
# superar
# superior
# supuestamente
# supuesto
# susceptible
# sushi
# susto
# sweet
# sólo
# t
# ta
# taaar
# tabaco
# tal
# talk
# talvez
# tamano
# también
# tampoco
# tanto
# tapa
# tardar
# tarde
# target
# tarj
# tarjeta
# tato
# tatuar
# tatuei
# taza
# tbm
# team
# teecer
# telepizza
# tema
# temblor
# tendencia
# tener
# teng
# ter
# tercero
# tere
# tere3
# terecon
# tereopinion
# terer
# teresa
# teresita
# tereso
# tereson
# terey
# terminar
# termino
# termometro
# terremoto
# terreno
# testimonio
# the
# they
# this
# thrones
# ticket
# tie
# tiem
# tiempo
# tienda
# tigrillo
# tildado
# timeline
# tipico
# tipo
# tirate
# tiratealaguo
# tirin
# tiro
# titular
# to
# tocar
# tocayo
# tod
# todavía
# todo
# tomar
# tomate
# tomo
# tonga
# tongo
# tonito
# top
# torniquete
# torpemente
# total
# toxico
# tra
# trabaj
# trabajador
# trabajar
# trabajo
# tracalado
# tradi
# tradición
# traducir
# tragar
# trajr
# tranquilo
# tratar
# traumado
# trei
# treintanero
# tremendo
# trend
# tres
# trinka
# triple
# triste
# triunfo
# tronco
# tssss
# tuberio
# tuco
# tugurio
# tuit
# tuiteado
# tuiter
# tuitero
# tuiteros
# tuits
# turista
# turrisimo
# turro
# tutorial
# tuza
# tw
# tweet
# twists
# twitteaste
# twitter
# twitterec
# tú
# u
# uber
# ubicación
# ud
# uds
# udstedes
# uffff
# ultimamente
# ultimo
# um
# uma
# underssss
# unico
# universo
# uno
# up
# urdesa
# usar
# uso
# usual
# usuario
# utilidad
# utilizado
# uuuffff
# v
# vacio
# vago
# vaina
# valer
# valeverguismo
# valor
# valorado
# valorar
# van
# variedad
# varios
# vayas
# vecino
# veia
# veja
# vender
# vendio
# venerar
# venezuela
# venir
# venta
# ventajosamente
# ver
# verdad
# verdadero
# verde
# verga
# vergo
# verguenza
# vergui
# version
# vestidura
# vez
# via
# viajar
# viaje
# vibra
# vicente
# vida
# vidal
# vidrio
# viejo
# vino
# visita
# visitar
# visito
# visión
# visto
# vivar
# vivir
# vivo
# voce
# volar
# volver
# volvio
# vomito
# votar
# vou
# voz
# vs
# vuelo
# vuelta
# vuelto
# vv
# vídeo
# wait
# wakanda
# wallstreet
# wan
# we
# webada
# webas
# wevada
# wharever
# wifi
# wtf
# x
# xd
# xenofobico
# xi
# xicar
# xq
# xupando
# y
# yalaaaaar
# yijadi
# yo
# yogurt
# yoongi
# yuc
# yulan
# yyy
# zarumo
# zaver
# zona
# él
# éxito

# %%
#@title categorías seleccionadas
categorias = {
"costo": ["valor", "afrentoso", "barato", "costo", "caro", "excesivo", "carisimo", "cobro", "cobrar", "consumismo", "dinero", "efectivo", "gasto", "sobrevalorado" ],
"servicio al cliente": ["agradable", "amargado", "amistad", "amor", "amiga", "atender", "bruja", "domicilio", "esperar", "feliz", "felicita", "frustración","exito","posicionado","mejor"],
"variedad": ["actualizar", "agregar", "autentico", "categoria", "combinacion","mixto" ],
"producto": ["malo","malisimo","turro","turrisimo","toxica","toxico","bolon", "aroma", "asqueroso", "basura", "bello", "bien", "bolon", "bonito","bueno", "buenisimo", "calidad",
             "gastronomia", "gastronomico", "gourmet", "sabroso", "horrible", "intenso", "sopudo", "calidad"]

}

# %% [markdown]
# ### Number of tweets per category

# %%
def count_texts_by_category(df, categories):
  category_counts = {}
  for category, keywords in categories.items():
    category_count = 0
    for text in df["text_processed"]:
      if any(keyword in text for keyword in keywords):
        category_count += 1
    category_counts[category] = category_count
  return category_counts

category_counts = count_texts_by_category(df, categorias)

for category, count in category_counts.items():
  print(f"Category: {category}, Count: {count}")
# Out:
# Category: costo, Count: 915
# Category: servicio al cliente, Count: 1333
# Category: variedad, Count: 70
# Category: producto, Count: 2223

# %%
# Sort the data by count
sorted_categories = sorted(category_counts.items(), key=lambda item: item[1], reverse=True)

# Crear el bar plot
fig, ax = plt.subplots(figsize=(10, 4))
sns.barplot(
    x=[count for _, count in sorted_categories],
    y=[category for category, _ in sorted_categories],
    palette="YlOrBr_r",
)

ax.set_title("Categorías de comentarios", fontdict={"size": 16})
ax.set_xlabel("Número de comentarios", fontdict={"size": 14})
ax.set_ylabel("Categoría", fontdict={"size": 14})

# Ajuste del espacio entre barras
ax.bar_label(ax.containers[0])
plt.tight_layout()


plt.show()
# Out:
# /tmp/ipykernel_1975/2884102949.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Agrega una columna por categoría y poner "flags" de si pertenece o no pertenece a dicho grupo

for category, keywords in categorias.items():
  df[category] = df["text_processed"].apply(lambda text: any(keyword in text for keyword in keywords))

display(
    df
)
# Out:
#       Unnamed: 0                   id             user  \
# 0              0  1192602342434234371     cesar_jurado
# 1              1  1192600432020996097    donoso_molina
# 2              2  1192593176378445826        LexyLucin
# 3              3  1192585514941112326           Cjvs12
# 4              4  1192583767489204225  DrStrangGuayaco
# ...          ...                  ...              ...
# 4009        4009  1191750188760739840        juano1092
# 4010        4010  1191749988063358976          pmora_7
# 4011        4011  1191749913903816704       dampuero17
# 4012        4012  1191749825290801152         gaferoto
# 4013        4013  1191749625373437958           emer24
#
#                                          mentions  count_mentions  \
# 0                              ['joacosaavedraq']               1
# 1            ['FranFerreroMD', 'fraguaciudadana']               2
# 2                               ['Belliiisima89']               1
# 3                                 ['Mano_Hostil']               1
# 4                                              []               0
# ...                                           ...             ...
# 4009                ['_SantinoBoy', 'CafedeTere']               2
# 4010                ['_SantinoBoy', 'CafedeTere']               2
# 4011                ['_SantinoBoy', 'CafedeTere']               2
# 4012  ['_SantinoBoy', 'CafedeTere', 'CafedeTere']               3
# 4013                ['_SantinoBoy', 'CafedeTere']               2
#
#       favourites_count  followers_count  friends_count            location  \
# 0                 1512              224            397           Guayaquil
# 1                   38               37             28     Guayas, Ecuador
# 2                   41                5            119                 NaN
# 3                 1556               32            532  Guayaquil, Ecuador
# 4                 4008             5978           1780         MultiVersos
# ...                ...              ...            ...                 ...
# 4009            108307              387            580      Quito, Ecuador
# 4010              3247               36            266      Quito, Ecuador
# 4011             21737              604           1729                 NaN
# 4012              7385             1871           4999             Ecuador
# 4013              2014              523           1867       New York, USA
#
#                                                   place  \
# 0                                                   NaN
# 1     {'attributes': {}, 'bounding_box': {'coordinat...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4009                                                NaN
# 4010                                                NaN
# 4011                                                NaN
# 4012                                                NaN
# 4013                                                NaN
#
#                                                    text  is_respuesta  \
# 0     RT @joacosaavedraq: Larga vida al bolón mixto ...          True
# 1     @FranFerreroMD @fraguaciudadana Buenas, estima...         False
# 2     RT @Belliiisima89: En el Pais de Alvarito, el ...          True
# 3     RT @Mano_Hostil: Desde la mañana los veo publi...          True
# 4     La verdad hasta ahora no entiendo la joda con ...         False
# ...                                                 ...           ...
# 4009  RT @_SantinoBoy: Nunca he comido en el @Cafede...          True
# 4010  RT @_SantinoBoy: Nunca he comido en el @Cafede...          True
# 4011  @_SantinoBoy @CafedeTere Pues sí, tiene sus de...         False
# 4012  @_SantinoBoy @CafedeTere Son muy buenos los bo...         False
# 4013  @_SantinoBoy @CafedeTere Uds comen Bolon? \nha...         False
#
#       id_tweet_origen user_tweet_origen  \
# 0        1.192197e+18    joacosaavedraq
# 1                 NaN               NaN
# 2        1.192188e+18     Belliiisima89
# 3        1.192533e+18       Mano_Hostil
# 4                 NaN               NaN
# ...               ...               ...
# 4009     1.191748e+18       _SantinoBoy
# 4010     1.191748e+18       _SantinoBoy
# 4011              NaN               NaN
# 4012              NaN               NaN
# 4013              NaN               NaN
#
#                                          text_processed  costo  \
# 0     largo vida bolon mixto maduro tere vida siempr...  False
# 1     buen estimar creer nacimiento bolon tere remon...  False
# 2     país alvarito bolon tere ir aceptar tarjeta cr...  False
# 3     manana ver publicar foto ewan gye cada foto me...  False
# 4     verdad ahora entender jodar bolon tere decir p...  False
# ...                                                 ...    ...
# 4009  nunca comer leer acomplejado quejar él exito s...  False
# 4010  nunca comer leer acomplejado quejar él exito s...  False
# 4011                           pues detractor fiel acar  False
# 4012       buen bolón calidad siempre ir costar persona  False
# 4013  uds comen bolon hahahhaha mejor olvdes salsa a...  False
#
#       servicio al cliente  variedad  producto
# 0                   False      True      True
# 1                   False     False      True
# 2                   False     False      True
# 3                   False     False     False
# 4                   False     False      True
# ...                   ...       ...       ...
# 4009                 True     False     False
# 4010                 True     False     False
# 4011                False     False     False
# 4012                False     False      True
# 4013                 True     False      True
#
# [4006 rows x 19 columns]

# %%
df.loc[:, ['costo', 'servicio al cliente', 'variedad', 'producto']].sum()
# Out:
# costo                   915
# servicio al cliente    1333
# variedad                 70
# producto               2223
# dtype: int64

# %%
category_counts = df.loc[:, ['costo', 'servicio al cliente', 'variedad', 'producto']].sum()
total_tweets = len(df)

category_percentages = (category_counts / total_tweets) * 100

print("Percentage of tweets per category (out of total tweets):")
print(category_percentages)
# Out:
# Percentage of tweets per category (out of total tweets):
# costo                  22.840739
# servicio al cliente    33.275087
# variedad                1.747379
# producto               55.491762
# dtype: float64

# %% [markdown]
# ### Sentiment analysis by category

# %%
# !pip install sentiment-analysis-spanish
# Out:
# Collecting sentiment-analysis-spanish
#   Downloading sentiment_analysis_spanish-0.0.25-py3-none-any.whl.metadata (2.7 kB)
# Downloading sentiment_analysis_spanish-0.0.25-py3-none-any.whl (30.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.0/30.0 MB 31.5 MB/s eta 0:00:00
# Installing collected packages: sentiment-analysis-spanish
# Successfully installed sentiment-analysis-spanish-0.0.25

# %%
import re
from sentiment_analysis_spanish import sentiment_analysis

sentiment_model = sentiment_analysis.SentimentAnalysisSpanish()

def normalize_text(text):
    text = text.lower()
    text = re.sub(r'(.)\1+', r'\1', text)  # remove repetitions
    return text

def compute_sentiment(text):
    if pd.isna(text):
        return None, "Neutral"

    try:
        text = normalize_text(text)
        score = sentiment_model.sentiment(text)

        if score < 0.45:
            label = "Negativo"
        elif score > 0.55:
            label = "Positivo"
        else:
            label = "Neutral"

        return score, label

    except Exception:
        return None, "Neutral"

df[["sentiment_score", "sentiment"]] = df["text_processed"].apply(
    lambda x: pd.Series(compute_sentiment(x))
)
df
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator CountVectorizer from version 0.23.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator MultinomialNB from version 0.23.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#       Unnamed: 0                   id             user  \
# 0              0  1192602342434234371     cesar_jurado
# 1              1  1192600432020996097    donoso_molina
# 2              2  1192593176378445826        LexyLucin
# 3              3  1192585514941112326           Cjvs12
# 4              4  1192583767489204225  DrStrangGuayaco
# ...          ...                  ...              ...
# 4009        4009  1191750188760739840        juano1092
# 4010        4010  1191749988063358976          pmora_7
# 4011        4011  1191749913903816704       dampuero17
# 4012        4012  1191749825290801152         gaferoto
# 4013        4013  1191749625373437958           emer24
#
#                                          mentions  count_mentions  \
# 0                              ['joacosaavedraq']               1
# 1            ['FranFerreroMD', 'fraguaciudadana']               2
# 2                               ['Belliiisima89']               1
# 3                                 ['Mano_Hostil']               1
# 4                                              []               0
# ...                                           ...             ...
# 4009                ['_SantinoBoy', 'CafedeTere']               2
# 4010                ['_SantinoBoy', 'CafedeTere']               2
# 4011                ['_SantinoBoy', 'CafedeTere']               2
# 4012  ['_SantinoBoy', 'CafedeTere', 'CafedeTere']               3
# 4013                ['_SantinoBoy', 'CafedeTere']               2
#
#       favourites_count  followers_count  friends_count            location  \
# 0                 1512              224            397           Guayaquil
# 1                   38               37             28     Guayas, Ecuador
# 2                   41                5            119                 NaN
# 3                 1556               32            532  Guayaquil, Ecuador
# 4                 4008             5978           1780         MultiVersos
# ...                ...              ...            ...                 ...
# 4009            108307              387            580      Quito, Ecuador
# 4010              3247               36            266      Quito, Ecuador
# 4011             21737              604           1729                 NaN
# 4012              7385             1871           4999             Ecuador
# 4013              2014              523           1867       New York, USA
#
#                                                   place  ... is_respuesta  \
# 0                                                   NaN  ...         True
# 1     {'attributes': {}, 'bounding_box': {'coordinat...  ...        False
# 2                                                   NaN  ...         True
# 3                                                   NaN  ...         True
# 4                                                   NaN  ...        False
# ...                                                 ...  ...          ...
# 4009                                                NaN  ...         True
# 4010                                                NaN  ...         True
# 4011                                                NaN  ...        False
# 4012                                                NaN  ...        False
# 4013                                                NaN  ...        False
#
#       id_tweet_origen  user_tweet_origen  \
# 0        1.192197e+18     joacosaavedraq
# 1                 NaN                NaN
# 2        1.192188e+18      Belliiisima89
# 3        1.192533e+18        Mano_Hostil
# 4                 NaN                NaN
# ...               ...                ...
# 4009     1.191748e+18        _SantinoBoy
# 4010     1.191748e+18        _SantinoBoy
# 4011              NaN                NaN
# 4012              NaN                NaN
# 4013              NaN                NaN
#
#                                          text_processed  costo  \
# 0     largo vida bolon mixto maduro tere vida siempr...  False
# 1     buen estimar creer nacimiento bolon tere remon...  False
# 2     país alvarito bolon tere ir aceptar tarjeta cr...  False
# 3     manana ver publicar foto ewan gye cada foto me...  False
# 4     verdad ahora entender jodar bolon tere decir p...  False
# ...                                                 ...    ...
# 4009  nunca comer leer acomplejado quejar él exito s...  False
# 4010  nunca comer leer acomplejado quejar él exito s...  False
# 4011                           pues detractor fiel acar  False
# 4012       buen bolón calidad siempre ir costar persona  False
# 4013  uds comen bolon hahahhaha mejor olvdes salsa a...  False
#
#       servicio al cliente  variedad  producto  sentiment_score  sentiment
# 0                   False      True      True         0.080201   Negativo
# 1                   False     False      True         0.782429   Positivo
# 2                   False     False      True         0.072065   Negativo
# 3                   False     False     False         0.010670   Negativo
# 4                   False     False      True         0.016428   Negativo
# ...                   ...       ...       ...              ...        ...
# 4009                 True     False     False         0.126604   Negativo
# 4010                 True     False     False         0.126604   Negativo
# 4011                False     False     False         0.196651   Negativo
# 4012                False     False      True         0.541625    Neutral
# 4013                 True     False      True         0.038546   Negativo
#
# [4006 rows x 21 columns]

# %%
#Histograma del análisis de sentimientos encontrado
df.sentiment.hist(bins=20)
# Out:
# <Axes: >

# %%
# Discretizando
# -1: Negativo
#  0: Neutral
#  1: Positivo
df["sentiment"] = df["sentiment"].apply(lambda x: -1 if x == "Negativo" else (1 if x == "Positivo" else 0))
df.sentiment.hist()
# Out:
# <Axes: >

# %%
dict_df = {
    "category": [],
    "sentiment": [],
    "count": []
}

for cat in ["costo", "servicio al cliente", "variedad", "producto"]:
    df_grouped = df.loc[df[cat]==True, [cat, "sentiment"]].groupby("sentiment")[cat].sum()
    counts_forthis_cat = df_grouped.to_list()
    sentiment_values = list(df_grouped.index)
    vat_value = [cat]*len(counts_forthis_cat)
    dict_df['category'] += vat_value
    dict_df['sentiment'] += sentiment_values
    dict_df['count'] += counts_forthis_cat

df_sentiment = pd.DataFrame(dict_df)

# Map numerical sentiment values to string labels
df_sentiment["sentiment"] = df_sentiment["sentiment"].apply(lambda x: "Negativo" if x==-1 else "Positivo" if x==1 else "Neutral")

df_sentiment
# Out:
#                category sentiment  count
# 0                 costo  Negativo    889
# 1                 costo   Neutral      9
# 2                 costo  Positivo     17
# 3   servicio al cliente  Negativo   1274
# 4   servicio al cliente   Neutral     18
# 5   servicio al cliente  Positivo     41
# 6              variedad  Negativo     64
# 7              variedad   Neutral      2
# 8              variedad  Positivo      4
# 9              producto  Negativo   2044
# 10             producto   Neutral    101
# 11             producto  Positivo     78

# %%
#@title Viz Sentiments by Category

sns.set_theme(style="whitegrid")

# Crear el stacked bar plot
ax = sns.barplot(
    data=df_sentiment,
    x="category",
    y="count",
    hue="sentiment",
    palette="viridis",
    orient='v',
)

# Configurar viz
ax.set_title("Sentiment by Category", fontdict={"size": 16})
ax.set_xlabel("Category", fontdict={"size": 14})
ax.set_ylabel("N° tweets", fontdict={"size": 14})
ax.legend(labels=["Negativo", "Neutral", "Positivo"], handles=ax.get_legend().legend_handles, labelspacing=0.2)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    data=df_sentiment,
    x="count",
    y="category",
    hue="sentiment",
    palette=["red", "green"],
    ax=ax,
    orient="h"
)

ax.set_title("Sentiment by Category", fontdict={"size": 16})
ax.set_xlabel("N° tweets", fontdict={"size": 14})
ax.set_ylabel("Category", fontdict={"size": 14})

# Add legend for sentiment
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Negativo', 'Positivo'], title='Sentiment')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1975/2119139598.py:6: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(
# /tmp/ipykernel_1975/2119139598.py:22: UserWarning: Mismatched number of handles and labels: len(handles) = 3 len(labels) = 2
#   ax.legend(handles=handles, labels=['Negativo', 'Positivo'], title='Sentiment')
